# %% [markdown]
# <a href="https://colab.research.google.com/github/Thedoko10/ADS025/blob/master/Aula_05_Python_Lista04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: João Victor Souza da Silva
# Matrícula: 20114290002 
# Lista 4

#Ex 01

'''lado = int(input('\nInsira a quantidade de lados: '))
if lado<=2 or lado>5:
  while True:
    print('\nQuantidade de lados INCORRETO!')
    lado = int(input('\nInsira a quantidade de lados: '))   # Loop de verificação dos lados
    if lado>=3 and lado<=5:
      break
medida = float(input('\nInsira o valor dos lados do polígono: '))
if lado ==3:
  print('TRIÂGNGULO, possui', lado, 'lados. O valor da ÁREA é:',medida,'cm')
elif lado ==4:
  print('QUADRADO, possui', lado,'lados. O valor da ÁREA é:',medida,'cm')
elif lado ==5:
  print('PENTÁGONO, possui', lado, 'lados. O valor da ÁREA é:',medida,'cm')''' # Usando if e elif, para definir os polígonos

  #Ex 02

'''lado = int(input('\nInsira a quantidade de lados: '))
if lado<3 or lado>5:
  while True:
    print('\nQuantidade de lados INCORRETO!')
    if lado<3:                # Nova mensagem mostrada na tela, caso na for um POLÍGONO
      print('NÃO É UM POLÍGONO')
    if lado>5:
      print('POLÍGONO NÃO IDENTIFICADO')   
    lado = int(input('\nInsira a quantidade de lados: '))   # Loop de verificação dos lados
    if lado>=3 and lado<=5:
      break
medida = float(input('\nInsira o valor dos lados do polígono: '))
if lado ==3:
  print('TRIÂGNGULO, possui', lado, 'lados. O valor da ÁREA é:',medida,'cm')
elif lado ==4:
  print('QUADRADO, possui', lado,'lados. O valor da ÁREA é:',medida,'cm')
elif lado ==5:
  print('PENTÁGONO, possui', lado, 'lados. O valor da ÁREA é:',medida,'cm')''' # Usando if e elif, para definir os polígonos


#Ex 03
'''num1 = int(input('Insira o primeiro valor inteiro: '))
num2 = int(input('Insira o segundo valor inteiro: '))
num3 = int(input('Insira o terceiro valor inteiro: '))
lista = [num1, num2, num3]
set_lista = set(lista)                        # Usando 'set' para não imprimir valores repertidos
print('\nOs valores inseridos são: 'set_lista)
print('O maior dos números é: ', max(lista))'''

#Ex 04

'''med1 = float(input('Insira a primeira medida: '))
med2 = float(input('Insira a segunda medida: '))
med3 = float(input('Insira a terceira medida: '))
medidas = [med1, med2, med3]  # Colocando dentro de uma lista os números inseridos
print('\nMedidas dos lados do triângulo: ', medidas,)

if med1 == med2 and med2 == med3 and med1 == med3:    #Utilizando operadores para comparar as medidas
  print('Triângulo Equilátero possui os 3 lados iguais')

if med1 == med2 != med3 or med2 == med3 != med1 or med1 == med3 != med2:
    print('Triângulo Isóscele possui 2 lados iguais')

if med1 != med2 and med2 != med3 and med1 != med3:
  print('Triângulo Escaleno possui os 3 lados diferentes')'''

  #Ex 05

'''valor1 = int(input('Insira o primeiro ângulo: '))
valor2 = int(input('Insira o segundo ângulo: '))
valor3 = int(input('Insira o terceiro ângulo: '))
valores = [valor1, valor2, valor3]  # Colocando dentro de uma lista os valores
print('\nMedidas dos ângulos de um triângulo: ', valores,)

if valor1 == 90 or valor2 == 90 or valor3 == 90:   #Utilizando operadores para comparar os ângulos
  print('Triângulo Retângulo possui um ângulo reto igual a 90º')

if valor1 > 90 or valor2 > 90 or valor3 > 90:
    print('Triângulo Obtusângulo possui um ângulo maior que 90º')

if valor1 < 90 and valor2 < 90 and valor3 < 90:
  print('Triângulo Acutângulo possui três ângulos menores que 90º')'''


#Ex 06

'''valor = int(input('Insira o valor: '))
num = range(0,valor+1,1) #Utilizando range para ler até número que foi inserido
print(list(num))'''


#Ex 07

'''num = int(input('\nInsira um número entre 1 e 4: '))
if num<1 or num>4:
  while True:
    print('Entrada inválida!')  
    num = int(input('\nInsira um número entre 1 e 4: '))   # Loop de verificação dos números entre 1 e 4.
    if num>=1 and num<=4:
      break
print('O número escolhido foi:', num)'''

#Ex 08
'''Fazer um programa que receba vários valores inteiros no teclado (um valor a
cada iteração) e determine o maior dos colocados desde o inicio do programa. A
condição de término do programa é quando o usuário digitar zero.'''


#Ex 09

'''num = int(input('\nInsira um número de 4 dígitos: '))
if num<1000 or num>10000:
  while True:
    print('Apenas números com 4 dígitos!')  
    num = int(input('\nInsira um número de 4 dígitos: ')) #Loop para verificar o número de 4 dígitos
    if num>=1000 and num<=9999:
      break
print('\nO número escolhido foi:', num)

cal = list(str(num)) # Transformando o número em strig para pecorrer ele
print('Unidade =',cal[3])
print('Dezena =',cal[2])
print('Centena =',cal[1])
print('Milhar =',cal[0])'''
