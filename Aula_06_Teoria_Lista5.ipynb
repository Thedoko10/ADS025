# %% [markdown]
# <a href="https://colab.research.google.com/github/Thedoko10/ADS025/blob/master/Aula_06_Teoria_Lista5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: João Victor Souza da Silva
# Matrícula: 20114290002 
# Lista 5

#Ex 01

'''import statistics
l1 = [10,13,17,9,8,11,13,7]
MediaSimples = statistics.mean(l1)
print('A média simples é', round(MediaSimples,2),'cosumo(g)')

MediaHarm = statistics.harmonic_mean(l1)
print('A média harmônica é', round(MediaHarm,2),'cosumo(g)')

from scipy.stats.mstats import gmean
MediaGeom = gmean(l1)
print('A média geométrica é', round(MediaGeom,2),'cosumo(g)')

Moda = statistics.mode(l1)
print('A moda é', round(Moda,2),'cosumo(g)')

Variancia = statistics.variance(l1)
print('A variância é', round(Variancia,2),'cosumo(g)')

DesvPa = statistics.stdev(l1)
print('O desvio padrão é', round(DesvPa,2),'cosumo(g)')'''

#Ex 02


'''import statistics
l1 = [67,75,63,72,77,78,81,77,80]
MediaSimples = statistics.mean(l1)
print('A média simples é', round(MediaSimples,2))

MediaHarm = statistics.harmonic_mean(l1)
print('A média harmônica é', round(MediaHarm,2))

from scipy.stats.mstats import gmean
MediaGeom = gmean(l1)
print('A média geométrica é', round(MediaGeom,2))

Moda = statistics.mode(l1)
print('A moda é', round(Moda,2))

Mediana = statistics.median(l1)
print('A mediana é', round(Mediana,2))

Variancia = statistics.variance(l1)
print('A variância é', round(Variancia,2))

DesvPa = statistics.stdev(l1)
print('O desvio padrão é', round(DesvPa,2))'''

#Ex 03

'''import statistics
l1 = [4.0,4.5,5.0,5.0,5.0,5.0,5.5,6.0,6.0,6.5,6.5,6.5,6.5,7.0,7.0,7.0,7.0,7.0,7.0,
      7.5,8.5,9.0,9.0,9.0,9.5,10.0,10.0,10.5,10.5,11.0,12.0,12.5,13.0,13.0]

MediaSimples = statistics.mean(l1)
print('A média simples é', round(MediaSimples,2))

DesvPa = statistics.stdev(l1)
print('O desvio padrão é', round(DesvPa,2))

CV = (DesvPa/MediaSimples)*100
print('O Coeficiente de Variação é', round(CV,2), '%')'''

#Ex 04

'''import statistics
l1 = [12,15,18,22,17,14,18,23,29,12]
MediaSimples = statistics.mean(l1)
print('A média simples é', round(MediaSimples,2),'Ton.')

Mediana = statistics.median(l1)
print('A mediana é', round(Mediana,2),'Ton.')

DesvPa = statistics.stdev(l1)
print('O desvio padrão é', round(DesvPa,2),'Ton.')'''

#Ex 05

'''notas_al = [] #Para guardar os números inseridos pelo input
nota = float(input('Insira o número 0, para entrar no programa: '))
if nota>=0 and nota<=10:
  while True:  #Loop para inserir diversos números
    nota = float(input('Insira as notas dos alunos, entre 0 e 10: '))
    if nota>=0 and nota<=10:
      notas_al.append(nota) #Colocando os números dentro do [] da variável
      print(notas_al)
    elif nota <0 and nota >10:
      print('Insira uma nota correta, entre 0 e 10')
      nota = float(input('Insira as notas dos alunos, entre 0 e 10: '))
    if nota == -999:
      print('\nSaiu do programa')
      break

import statistics        #Comandos estatísticos
MediaSimples = statistics.mean(notas_al)
print('\nA média simples é', round(MediaSimples,2))

from scipy.stats.mstats import gmean
MediaGeom = gmean(notas_al)
print('A média geométrica é', round(MediaGeom,2))

MediaHarm = statistics.harmonic_mean(notas_al)
print('A média harmônica é', round(MediaHarm,2))

Variancia = statistics.variance(notas_al)
print('A variância é', round(Variancia,2))

DesvPa = statistics.stdev(notas_al)
print('O desvio padrão é', round(DesvPa,2))

CV = (DesvPa/MediaSimples)*100
print('O Coeficiente de Variação é', round(CV,2), '%')

Moda = statistics.mode(notas_al)
print('A moda é', round(Moda,2))'''

#Ex 06

'''nota1 = float(input('Insira a primeira nota (entre 0 e 10): '))
nota2 = float(input('Insira a segunda nota (entre 0 e 10): '))
nota3 = float(\ninput('Insira a terceira nota (entre 0 e 10): '))
lista_notas = [nota1, nota2, nota3] # Guardar as notas na variável dentro []

mediap = (nota1*3 + nota2*4 + nota3*3) / (3+4+3) #Calculo para média ponderada
print('A média ponderada das notas são:',mediap)'''
# Out:
# Insira a primeira nota (entre 0 e 10): 10
# Insira a segunda nota (entre 0 e 10): 10
# Insira a terceira nota (entre 0 e 10): 10
# A média ponderada das notas são: 10.0
